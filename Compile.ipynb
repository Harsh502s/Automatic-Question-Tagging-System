# %%
import pandas as pd
for i in range(1,20):
    try:
        df = pd.read_csv(f'Data/data{i}.csv')
        print('-'*50)
        print('DATA:',i)
        print('-'*50)
        print(df.isna().sum())
    except:
        pass
    pass
# Out:
# --------------------------------------------------
# DATA: 1
# --------------------------------------------------
# Head             15
# Body             15
# Tags             16
# First Answer    688
# dtype: int64
# --------------------------------------------------
# DATA: 2
# --------------------------------------------------
# Head              2
# Body              2
# Tags              3
# First Answer    663
# dtype: int64
# --------------------------------------------------
# DATA: 3
# --------------------------------------------------
# Head             15
# Body             15
# Tags             16
# First Answer    688
# dtype: int64
# --------------------------------------------------
# DATA: 4
# --------------------------------------------------
# Head              0
# Body              0
# Tags              1
# First Answer    598
# dtype: int64
# --------------------------------------------------
# DATA: 5
# --------------------------------------------------
# ...
