# %%
import pandas as pd
for i in range(1,20):
    try:
        df = pd.read_csv(f'Data/data{i}.csv')
        print('-'*50)
        print('DATA:',i)
        print('-'*50)
        print(df.isna().sum())
    except:
        pass
    pass
# Out:
# --------------------------------------------------
# DATA: 1
# --------------------------------------------------
# Head             15
# Body             15
# Tags             16
# First Answer    688
# dtype: int64
# --------------------------------------------------
# DATA: 2
# --------------------------------------------------
# Head              2
# Body              2
# Tags              3
# First Answer    663
# dtype: int64
# --------------------------------------------------
# DATA: 3
# --------------------------------------------------
# Head             15
# Body             15
# Tags             16
# First Answer    688
# dtype: int64
# --------------------------------------------------
# DATA: 4
# --------------------------------------------------
# Head              0
# Body              0
# Tags              1
# First Answer    598
# dtype: int64
# --------------------------------------------------
# DATA: 5
# --------------------------------------------------
# Head              0
# Body              0
# Tags              0
# First Answer    650
# dtype: int64
# --------------------------------------------------
# DATA: 6
# --------------------------------------------------
# Head              0
# Body              0
# Tags              0
# First Answer    634
# dtype: int64
# --------------------------------------------------
# DATA: 7
# --------------------------------------------------
# Head              0
# Body              0
# Tags              1
# First Answer    607
# dtype: int64
# --------------------------------------------------
# DATA: 8
# --------------------------------------------------
# Head              0
# Body              0
# Tags              3
# First Answer    649
# dtype: int64
# --------------------------------------------------
# DATA: 9
# --------------------------------------------------
# Head              0
# Body              0
# Tags              0
# First Answer    544
# dtype: int64
# --------------------------------------------------
# DATA: 10
# --------------------------------------------------
# Head             20
# Body             20
# Tags             20
# First Answer    596
# dtype: int64
# --------------------------------------------------
# DATA: 11
# --------------------------------------------------
# Head              0
# Body              0
# Tags              0
# First Answer    246
# dtype: int64
# --------------------------------------------------
# DATA: 12
# --------------------------------------------------
# Head               0
# Body               0
# Tags               0
# First Answer    1654
# dtype: int64
# --------------------------------------------------
# DATA: 13
# --------------------------------------------------
# Head              19
# Body              19
# Tags              19
# First Answer    1658
# dtype: int64
# --------------------------------------------------
# DATA: 14
# --------------------------------------------------
# Head               0
# Body               0
# Tags               0
# First Answer    2219
# dtype: int64
# --------------------------------------------------
# DATA: 15
# --------------------------------------------------
# Head               1
# Body             203
# Tags             204
# First Answer    2220
# dtype: int64
# --------------------------------------------------
# DATA: 16
# --------------------------------------------------
# Head               0
# Body               0
# Tags               5
# First Answer    2194
# dtype: int64
# --------------------------------------------------
# DATA: 17
# --------------------------------------------------
# Head               0
# Body               0
# Tags               0
# First Answer    2393
# dtype: int64
# --------------------------------------------------
# DATA: 18
# --------------------------------------------------
# Head               0
# Body               0
# Tags               0
# First Answer    2865
# dtype: int64
# --------------------------------------------------
# DATA: 19
# --------------------------------------------------
# Head              23
# Body              23
# Tags              23
# First Answer    3878
# dtype: int64

# %%
df1 = pd.read_csv('Data/data1.csv')
df2 = pd.read_csv('Data/data2.csv')
df3 = pd.read_csv('Data/data3.csv')
df4 = pd.read_csv('Data/data4.csv')
df5 = pd.read_csv('Data/data5.csv')
df6 = pd.read_csv('Data/data6.csv')
df7 = pd.read_csv('Data/data7.csv')
df8 = pd.read_csv('Data/data8.csv')
df9 = pd.read_csv('Data/data9.csv')
df10 = pd.read_csv('Data/data10.csv')
df11 = pd.read_csv('Data/data11.csv')
df12 = pd.read_csv('Data/data12.csv')
df13 = pd.read_csv('Data/data13.csv')
df14 = pd.read_csv('Data/data14.csv')
df15 = pd.read_csv('Data/data15.csv')
df16 = pd.read_csv('Data/data16.csv')
df17 = pd.read_csv('Data/data17.csv')
df18 = pd.read_csv('Data/data18.csv')
df19 = pd.read_csv('Data/data19.csv')

# %%
list_of_df = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19]
combined_df = pd.concat(list_of_df, axis=0, ignore_index=True)

# %%
combined_df.to_csv('Data/combined_df.csv', index=False)
